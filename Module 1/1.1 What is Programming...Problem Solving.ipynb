# %% [markdown]
# # So what is programming?

# %% [markdown]
# According to the definition from [Oxford Languages](https://languages.oup.com/google-dictionary-en/)
# ![definition.png](attachment:definition.png)

# %% [markdown]
# I guess it is obvious from the 2 definitions that we are interested in the no 1. definition that explains programmmiing as the process of writing computer programs. Now what are computer programs?

# %% [markdown]
# A computer program consists of code that is executed on a computer to perform particular tasks. Programming is the process of giving machines a set of instructions that describe how a program should be carried out.
#
#
# So simply put, this is telling the computer how to solve a problem to the end that the computer solves the problem.
#
# Programming is a creative task: there is no right or wrong way to solve a problem, in the same way, that there is no right or wrong way to paint a picture.
#
# There are choices to be made, and one way may seem better than another, but that doesn’t mean the other is wrong! With the right skills and experience, a programmer can craft software to solve an unlimited number of problems – from telling you when your next train will arrive at playing your favourite music.
#
# The possibilities are constrained only by your imagination. That is why programming is fun

# %% [markdown]
# # Brain Teaser
# Type the step by step process of how you to play your favourite sport. You want to give the process to your friend in the stone age who has never participated any sport before.
#
# Note:Do not assume that your "stone age" friend should know what to do.

# %% [markdown]
# ## Giving your computer instructions(programming)
# When you create a program for a computer robot( [C-3PO](https://www.starwars.com/databank/c-3po)), you give it a set of instructions, which it will run one at a time in order, precisely as given. If you told him to jump into a waterfall, he would!
#
# ![c3.jpg](attachment:c3.jpg)
#
# 1. turn and face the waterfall
# 2. walk towards the waterfall
# 3. stop at the edge of the waterfall
# 4. jump off the waterfall
#
# To stop him from constantly falling off cliffs, they can also make choices about what to do next:
#
# 5. If I won't survive the fall, don't jump off the cliff
#
# Computers never get bored and are really good at doing the same thing over and over again. Instruction 2 above might look in more detail like this:
#
#  2. (a)left foot forward
#  2. (b)right foot forward
#  2. (c)go back to 2a
#
# Let us get a bit ahead of ourselves, these three concepts are the basic logical structures in computer programming:

# %% [markdown]
#  Sequence: running instructions in order
#
#
#  Selection: making choices
#
#
#  Repetition: doing the same thing more than once, also called iteration
#
# Add to these concepts the ability to deal with inputs and outputs and to store data, and you have the tools to solve the majority of all computing problems.

# %% [markdown]
# ## Programming Languages
#
# Unfortunately, computers don’t understand languages like English or Spanish, so we have to use a programming language they understand to give them instructions.
#
#
#
# There are many different programming languages, all of which have their own merits, and certain languages are better suited to particular types of tasks, but there is no one language that is the ‘best’.
#
#
#
# In this course, you will be programming using a language called Python. Python is one of a group of languages called “general-purpose programming languages”, which can be used to solve a wide variety of problems. Other popular languages in this category are C, Ruby, Java and BASIC.
#
#
#
# This is a small Python program that asks the user to enter their name and says “Hi” to them:
#
# ![hello.png](attachment:hello.png)

# %% [markdown]
# You don’t need to be a computer programmer to be able to read this code. It contains English words and it is readable (if not perhaps understandable). However, by the end of this course you will understand this code, what it does, and the concepts it uses.
#
# Programs are often referred to as code and hence programming is also known as coding.

# %% [markdown]
# ## Exercise 1 - Finish Set up
#
# There is a document in this module to help with the process of setting up your environment for the next module of this course.
#
# 1. SetUp your environment using the instructions in the "Setting Up Your Work Environment" Document.
# 2. Try to replicate the python program above and attempt an explanation of what is happening.
#
# You are all good for the next module!
